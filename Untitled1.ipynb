# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # This is a cool paper
#
# ## with an even cooler subtitle
#
# $$
# \int_0^t f(s)ds
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.plot(np.sin(np.linspace(0.0, 10.0, 100)))

# %%
plt.
